# %%
import math
# import pandas_datareader as web
import tushare as ts
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
pro = ts.pro_api()

# %%
model = Sequential()
model.add(Dense(1))

# %%
model.compile(optimizer='sgd', loss="mean_squared_error")

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs, ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 58.9631
# Epoch 2/500
# 1/1 [==============================] - 0s 997us/step - loss: 46.8167
# Epoch 3/500
# 1/1 [==============================] - 0s 999us/step - loss: 37.2518
# Epoch 4/500
# 1/1 [==============================] - 0s 998us/step - loss: 29.7179
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 23.7823
# Epoch 6/500
# 1/1 [==============================] - 0s 0s/step - loss: 19.1041
# Epoch 7/500
# 1/1 [==============================] - 0s 998us/step - loss: 15.4155
# Epoch 8/500
# 1/1 [==============================] - 0s 997us/step - loss: 12.5055
# Epoch 9/500
# 1/1 [==============================] - 0s 999us/step - loss: 10.2084
# Epoch 10/500
# 1/1 [==============================] - 0s 996us/step - loss: 8.3935
# Epoch 11/500
# 1/1 [==============================] - 0s 997us/step - loss: 6.9582
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.975504]]

# %%
pro = ts.pro_api()

df = pro.index_basic(market='SSE')
df
# Out:
#        ts_code         name market publisher category base_date  base_point  \
# 0    000001.SH         上证指数    SSE      中证公司     综合指数  19901219      100.00
# 1    000002.SH         上证A指    SSE      中证公司     综合指数  19901219      100.00
# 2    000003.SH         上证B指    SSE      中证公司     综合指数  19920221      100.00
# 3    000004.SH      上证工业类指数    SSE      中证公司     综合指数  19930430     1358.78
# 4    000005.SH      上证商业类指数    SSE      中证公司     综合指数  19930430     1358.78
# ..         ...          ...    ...       ...      ...       ...         ...
# 590  n50113.SH  沪质中高债3-5(利)    SSE       上交所     债券指数  20081231      100.00
# 591  n50117.SH     上证绿色债(利)    SSE       上交所     债券指数  20161230      100.00
# 592  n50118.SH   上证绿色公司债(利)    SSE       上交所     债券指数  20161230      100.00
# 593   S812T.SH      S812T指数    SSE      中证公司     规模指数  20191231     1000.00
# 594  T00901.SH      小康指数(旧)    SSE      中证公司     主题指数  20051230     1000.00
#
#     list_date
# 0    19910715
# 1    19920221
# ...

# %%
#获取深圳市场20200320各板块交易数据
df = pro.daily_info(trade_date='20210203', ts_code='SZ_A', exchange='SZ')
df
# Out:
#   trade_date ts_code ts_name  com_count  total_share  float_share  \
# 0   20210203    SZ_A  深圳主板A股        459  8320.523744  98100.07263
#
#       total_mv      float_mv       amount         vol trans_count    pe    tr  \
# 0  7383.180953  88239.188258  1298.095179  111.871564        None  None  None
#
#   exchange
# 0       SZ

# %%
df = pro.index_daily(ts_code='399001.SZ', start_date='20210101', end_date='20210201')
df[df['change']>100]
# Out:
#       ts_code trade_date       close        open        high         low  \
# 0   399001.SZ   20210201  15024.2443  14841.7134  15036.3846  14797.4130
# 6   399001.SZ   20210122  15628.7304  15508.9378  15632.3340  15381.6033
# 7   399001.SZ   20210121  15520.5980  15251.6686  15608.3841  15251.6686
# 8   399001.SZ   20210120  15223.3575  15023.7377  15246.7773  14958.2191
# 10  399001.SZ   20210118  15269.2724  14980.5049  15309.7901  14898.8796
# 14  399001.SZ   20210112  15460.0321  15053.8722  15460.0321  15020.2604
# 17  399001.SZ   20210107  15356.4035  15178.3476  15356.4035  15101.6671
# 19  399001.SZ   20210105  15147.5693  14760.2525  15149.0965  14716.7892
# 20  399001.SZ   20210104  14827.4686  14516.1215  14859.0865  14486.2519
#
#      pre_close    change  pct_chg          vol       amount
# 0   14821.9946  202.2497   1.3645  337066645.0  485262020.0
# 6   15520.5980  108.1324   0.6967  396161439.0  628223686.1
# ...

# %%
df = pro.shibor(start_date='20210101', end_date='20210206')
df
# Out:
#         date     on     1w     2w     1m     3m     6m     9m     1y
# 0   20210205  1.909  2.338  2.877  2.753  2.779  2.807  2.932  3.007
# 1   20210204  2.075  2.324  2.644  2.752  2.776  2.807  2.920  3.002
# 2   20210203  1.859  2.146  2.585  2.772  2.776  2.807  2.916  3.002
# 3   20210202  2.313  2.241  2.715  2.807  2.775  2.805  2.910  3.003
# 4   20210201  2.795  3.194  3.283  2.850  2.773  2.802  2.902  2.998
# 5   20210129  3.282  3.071  3.798  2.832  2.765  2.796  2.896  2.989
# 6   20210128  3.024  2.981  3.555  2.708  2.705  2.756  2.859  2.962
# 7   20210127  2.970  2.969  3.064  2.632  2.619  2.707  2.827  2.936
# 8   20210126  2.726  2.728  2.853  2.547  2.589  2.699  2.802  2.906
# 9   20210125  2.450  2.296  2.681  2.512  2.579  2.691  2.791  2.892
# 10  20210122  2.436  2.271  2.601  2.503  2.578  2.688  2.789  2.883
# 11  20210121  2.573  2.359  2.651  2.489  2.578  2.688  2.789  2.875
# 12  20210120  2.457  2.493  2.619  2.464  2.575  2.688  2.789  2.866
# ...

# %%
df = pro.top10_floatholders(ts_code='600016.SH', start_date='20170101', end_date='20171231')
df
# Out:
#       ts_code  ann_date  end_date           holder_name   hold_amount
# 0   600016.SH  20180330  20171231     安邦财产保险股份有限公司-传统产品  1.665226e+09
# 1   600016.SH  20180330  20171231  安邦人寿保险股份有限公司-稳健型投资组合  2.369417e+09
# 2   600016.SH  20180330  20171231          中国证券金融股份有限公司  1.734652e+09
# 3   600016.SH  20180330  20171231          中国泛海控股集团有限公司  1.682652e+09
# 4   600016.SH  20180330  20171231   安邦保险集团股份有限公司-传统保险产品  1.639345e+09
# 5   600016.SH  20180330  20171231           新希望六和投资有限公司  1.523606e+09
# 6   600016.SH  20180330  20171231          上海健特生命科技有限公司  1.149733e+09
# 7   600016.SH  20180330  20171231  安邦人寿保险股份有限公司-稳健型投资组合  2.369417e+09
# 8   600016.SH  20180330  20171231   华夏人寿保险股份有限公司-万能保险产品  1.146469e+09
# 9   600016.SH  20180330  20171231              中国船东互保协会  1.086917e+09
# 10  600016.SH  20171031  20170930  安邦人寿保险股份有限公司-稳健型投资组合  2.369417e+09
# 11  600016.SH  20171031  20170930          中国证券金融股份有限公司  1.820370e+09
# ...

# %%
df = pro.stk_holdernumber(ts_code='600016.SH', start_date='20200101', end_date='20200201')
df = pro.stk_holdernumber(ts_code='300199.SZ', start_date='20200101', end_date='20200201')
df
# Out:
# Empty DataFrame
# Columns: [ts_code, ann_date, end_date, holder_num]
# Index: []

# %%
df = pro.stk_managers(ts_code='000001.SZ')
df
# Out:
#        ts_code  ann_date name gender    lev    title   edu national birthday  \
# 0    000001.SZ  20190604  姚贵平      M     高管      副行长    本科       中国     1961
# 1    000001.SZ  20190604  姚贵平      M  董事会成员     执行董事    本科       中国     1961
# 2    000001.SZ  20190604  姚贵平      M  委员会成员  战略委员会委员    本科       中国     1961
# 3    000001.SZ  20190309   吴鹏      M     高管      副行长    博士       中国     1965
# 4    000001.SZ  20190307  孙永桢      F     监事     职工监事    硕士       中国     1968
# ..         ...       ...  ...    ...    ...      ...   ...      ...      ...
# 277  000001.SZ  19941020  曾柯林      M     高管     副总经理    专科       中国     1938
# 278  000001.SZ  19940329  徐铁南   None  董事会成员     常务董事  None     None     None
# 279  000001.SZ  19930505  刘自强   None     高管      总经理  None     None     None
# 280  000001.SZ  19930505  刘自强   None  董事会成员       董事  None     None     None
# 281  000001.SZ  19930226  罗显荣   None  董事会成员      董事长  None     None     None
#
#     begin_date  end_date
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential(
    [
        layers.Dense(2, activation="relu", name="layer1"),
        layers.Dense(3, activation="relu", name="layer2"),
        layers.Dense(4, name="layer3"),
    ]
)
# Call model on a test input
x = tf.ones((3, 3))
y = model(x)

# %%
d = { 'Adam': 95, 'Lisa': 85, 'Bart': 59 }
for key in d:
    print(d[key])
# Out:
# 95
# 85
# 59

# %%
a = round(0.0001, 3)
a
# Out:
# 0.0

# %%
a = 0.0
b = 0.0
a == b
# Out:
# True

# %%
import pandas as pd
df = pd.DataFrame({"A" : [6, 2, 10, -5, 3],
                   "B" : [2, 5, 3, 2, 6],
                   "C" : [-5, 2, 1, 8, 2]})
df
# Out:
#     A  B  C
# 0   6  2 -5
# 1   2  5  2
# 2  10  3  1
# 3  -5  2  8
# 4   3  6  2

# %%
limits_dic = {"A" : 0, "B" : 2, "C" : 0}
query = ' & '.join(['{}>{}'.format(k, v) for k, v in limits_dic.items()])
query
# Out:
# 'A>0 & B>2 & C>0'

# %%
query = ' & '.join([f'{k}>{v}' for k, v in limits_dic.items()])
query
# Out:
# 'A>0 & B>2 & C>0'

# %%
temp = df.query(query)
temp
# Out:
#     A  B  C
# 1   2  5  2
# 2  10  3  1
# 4   3  6  2

# %%
df_stock = pd.DataFrame({'trade_date':['2010-01-01','2010-02-01','2010-03-01','2010-04-01','2010-05-01','2010-06-01'],
                    'vol':[4090,5000,4090,8500,6500,4000],
                   'ma25_slope':[0.04,0.05,0.004,0.15,0.25,0.01],
                   'ma60_slop':[0.070,0.080,0.090,0.0040,0.02,0.003]})

df_index = pd.DataFrame({'trade_date':['2010-01-01','2010-02-01','2010-03-01','2010-04-01','2010-05-01','2010-06-01'],
                    'vol':[409000,500000,40900,85000,650000,400000],
                   'ma25_slope':[-0.04,0.05,-0.004,0.15,0.25,0.01],
                   'ma60_slop':[0.070,0.080,-0.090,0.0040,-0.02,0.003]})
a = df_stock.query('vol>5000')
b = df_index.query('ma25_slope>0')
list(set(a['trade_date']).intersection(set(b['trade_date'])))
# Out:
# ['2010-05-01', '2010-04-01']

# %%
column = ['height', 'age', 'gender']
equal = ['>', '>', '==']
condition = [4, 20, 'M']

# %%
query = ' & '.join(f'{i} {j} {repr(k)}' for i, j, k in zip(column, equal, condition))
df.query('height>=5&age>40')
# Out:
#   gender  height  age
# 1      M       5   80

# %%
idx1 = pd.Index([1, 2, 3, 4])
idx2 = pd.Index([3, 4, 5, 6])
idx1.intersection(idx2)
# Out:
# Int64Index([3, 4], dtype='int64')

# %%
a = []
b = {'I': ['vol>0','ma25_slope>0','ma60_slope>0'], 'E':[]}
# b = {}
# b['I'] = ['vol>0','ma25_slope>0','ma60_slope>0']
# a.append({'I': ['vol>0','ma25_slope>0','ma60_slope>0']})
c = ' & '.join(b['I'])
# b
# b
c
# Out:
# 'vol>0 & ma25_slope>0 & ma60_slope>0'

# %%
b = {'I':'vol>0','ma25_slope>0'}
b
# Out:
#   File "<ipython-input-31-a75e0461ec15>", line 1
#     b = {'I':'vol>0','ma25_slope>0'}
#                                    ^
# SyntaxError: invalid syntax

# %%
import ast
a = ast.literal_eval("{'E': [], 'I': ['ma25_slope >= 0.05241']}")
a
# Out:
# {'E': [], 'I': ['ma25_slope >= 0.05241']}

# %%
df = ts.pro_bar(ts_code='000688.SH', asset='I', adj=None, freq='D',
                                     start_date='20200101', end_date='20210101')
df
# Out:
#        ts_code trade_date      close       open       high        low  \
# 0    000688.SH   20201231  1393.0272  1370.4413  1394.7391  1368.4700
# 1    000688.SH   20201230  1362.9107  1336.7202  1367.7624  1335.2072
# 2    000688.SH   20201229  1337.4696  1338.2399  1353.0612  1336.0901
# 3    000688.SH   20201228  1339.0068  1345.2989  1349.3496  1335.2532
# 4    000688.SH   20201225  1349.7931  1348.4717  1357.6506  1340.7892
# ..         ...        ...        ...        ...        ...        ...
# 238  000688.SH   20200108  1051.1599  1035.8362  1059.4361  1034.5129
# 239  000688.SH   20200107  1043.0833  1025.6627  1043.0833  1019.8577
# 240  000688.SH   20200106  1027.2773  1019.9989  1040.1404  1019.9989
# 241  000688.SH   20200103  1024.4819  1021.6693  1029.0713  1018.6813
# 242  000688.SH   20200102  1019.7234  1005.6174  1019.9098  1005.6174
#
#      pre_close   change  pct_chg         vol        amount
# 0    1362.9107  30.1165   2.2097  5460861.00  3.631690e+07
# ...

# %%
df = pro.cn_m(start_m='199001', end_m='202102')
df
# Out:
#       month        m0  m0_yoy  m0_mom         m1  m1_yoy  m1_mom         m2  \
# 0    202101  89600.00   -3.90    6.29  625600.00   14.70    0.00  2213000.0
# 1    202012  84300.00    9.20    3.31  625600.00    8.60    1.13  2186800.0
# 2    202011  81600.00   10.30    0.74  618600.00   10.00    1.54  2172000.0
# 3    202010  81000.00   10.40   -1.70  609200.00    9.10    1.15  2149700.0
# 4    202009  82400.00   11.10    3.00  602300.00    8.10    0.17  2164100.0
# ..      ...       ...     ...     ...        ...     ...     ...        ...
# 368  199005   2090.05    2.62   -1.86    5782.38    8.62    0.62        NaN
# 369  199004   2129.69    2.95   -1.16    5746.54    8.20    1.61        NaN
# 370  199003   2154.64    2.65   -5.80    5655.65    7.68   -0.10        NaN
# 371  199002   2287.20    1.42  -12.86    5661.44    6.10   -6.09        NaN
# 372  199001   2624.60    6.91   11.97    6028.46    7.51    3.40        NaN
#
#      m2_yoy  m2_mom
# 0       9.4    1.20
# ...

# %%
df = pro.cn_cpi(start_m='201801', end_m='201903')
df
# Out:
#      month  nt_val  nt_yoy  nt_mom  nt_accu  town_val  town_yoy  town_mom  \
# 0   201903   102.3     2.3    -0.4    101.8     102.3       2.3      -0.4
# 1   201902   101.5     1.5     1.0    101.6     101.5       1.5       1.0
# 2   201901   101.7     1.7     0.5    101.7     101.8       1.8       0.5
# 3   201812   101.9     1.9     0.0    102.1     101.9       1.9       0.0
# 4   201811   102.2     2.2    -0.3    102.1     102.2       2.2      -0.4
# 5   201810   102.5     2.5     0.2    102.1     102.5       2.5       0.2
# 6   201809   102.5     2.5     0.7    102.1     102.4       2.4       0.7
# 7   201808   102.3     2.3     0.7    102.0     102.3       2.3       0.6
# 8   201807   102.1     2.1     0.3    102.0     102.1       2.1       0.4
# 9   201806   101.9     1.9    -0.1    102.0     101.8       1.8       0.0
# 10  201805   101.8     1.8    -0.2    102.0     101.8       1.8      -0.2
# 11  201804   101.8     1.8    -0.2    102.1     101.8       1.8      -0.2
# ...

# %%
df = pro.cn_gdp(start_q='2018Q1', end_q='2019Q3')
df
# Out:
#   quarter       gdp  gdp_yoy       pi  pi_yoy        si  si_yoy        ti  \
# 0  2019Q3  712845.4      6.2  43005.0     2.9  276912.5     5.6  392927.9
# 1  2019Q2  460636.7      6.3  23207.0     3.0  179122.1     5.8  258307.5
# 2  2019Q1  218062.8      6.4   8769.4     2.7   81806.5     6.1  127486.9
# 3  2018Q4  900309.5      6.6  64734.0     3.5  366000.9     5.8  469574.6
# 4  2018Q3  646710.9      6.7  39799.8     3.4  261822.8     5.8  345088.2
# 5  2018Q2  417215.4      6.8  21576.2     3.2  168558.1     6.1  227081.1
# 6  2018Q1  197920.0      6.8   8574.4     3.2   77116.7     6.3  112229.0
#
#    ti_yoy
# 0     7.0
# 1     7.0
# 2     7.0
# 3     7.6
# 4     7.7
# 5     7.6
# 6     7.5

# %%
df = pro.cn_ppi(start_m='201905', end_m='202005')
df
# Out:
#      month  ppi_yoy  ppi_mp_yoy  ppi_mp_qm_yoy  ppi_mp_rm_yoy  ppi_mp_p_yoy  \
# 0   202005     -3.7        -5.1          -14.8           -9.9          -2.4
# 1   202004     -3.1        -4.5          -11.6           -8.8          -2.2
# 2   202003     -1.5        -2.4           -4.0           -5.2          -1.2
# 3   202002     -0.4        -1.0            1.1           -2.2          -0.7
# 4   202001      0.1        -0.4            4.7           -0.8          -0.6
# 5   201912     -0.5        -1.2            2.6           -2.6          -0.9
# 6   201911     -1.4        -2.5           -1.4           -5.0          -1.6
# 7   201910     -1.6        -2.6           -1.9           -5.6          -1.5
# 8   201909     -1.2        -2.0            0.6           -4.8          -1.2
# 9   201908     -0.8        -1.3            2.8           -3.5          -0.8
# 10  201907     -0.3        -0.7            3.2           -2.9          -0.2
# ...

# %%
df = pro.shibor(start_date='20180101', end_date='20181101')
df
# Out:
#          date      on     1w     2w      1m      3m      6m      9m      1y
# 0    20181101  2.5470  2.673  2.691  2.6960  2.9760  3.2970  3.5040  3.5500
# 1    20181031  2.3700  2.715  2.730  2.6890  2.9630  3.2980  3.5040  3.5500
# 2    20181030  1.5660  2.598  2.640  2.6630  2.9570  3.2950  3.5010  3.5500
# 3    20181029  1.8520  2.609  2.651  2.6720  2.9580  3.2970  3.5020  3.5500
# 4    20181026  2.0670  2.618  2.650  2.6730  2.9520  3.2970  3.5020  3.5500
# ..        ...     ...    ...    ...     ...     ...     ...     ...     ...
# 203  20180108  2.4610  2.737  3.720  4.2886  4.6594  4.7052  4.6989  4.7200
# 204  20180105  2.4840  2.745  3.749  4.3756  4.6637  4.7118  4.6990  4.7249
# 205  20180104  2.5050  2.760  3.802  4.4760  4.6870  4.7380  4.7020  4.7286
# 206  20180103  2.5635  2.785  3.870  4.6220  4.7300  4.7830  4.7110  4.7360
# 207  20180102  2.6570  2.839  3.943  4.7430  4.8040  4.8310  4.7150  4.7470
#
# [208 rows x 9 columns]

# %%
df = pro.shibor_lpr(start_date='20190101', end_date='20210130')
df
# Out:
#          date    1y
# 0    20191120  4.15
# 1    20191021  4.20
# 2    20190920  4.20
# 3    20190820  4.25
# 4    20190816  4.31
# ..        ...   ...
# 152  20190108  4.31
# 153  20190107  4.31
# 154  20190104  4.31
# 155  20190103  4.31
# 156  20190102  4.31
#
# [157 rows x 2 columns]

# %%
df = pro.libor(curr_type='GBP', start_date='20180101', end_date='20181130')
df
# Out:
#          date curr_type       on       1w       1m       2m       3m       6m  \
# 0    20181130       GBP  0.68175  0.70763  0.73650  0.77275  0.89338  1.01188
# 1    20181129       GBP  0.67663  0.70825  0.73250  0.77225  0.89819  1.00313
# 2    20181128       GBP  0.68513  0.71088  0.73575  0.76850  0.89356  1.00356
# 3    20181127       GBP  0.68125  0.71063  0.73563  0.76575  0.89175  1.00350
# 4    20181126       GBP  0.67750  0.71088  0.73550  0.76550  0.89213  1.00338
# ..        ...       ...      ...      ...      ...      ...      ...      ...
# 227  20180108       GBP  0.47370  0.48363  0.49131  0.50531  0.52081  0.57619
# 228  20180105       GBP  0.47486  0.48138  0.48931  0.50144  0.52125  0.57438
# 229  20180104       GBP  0.47266  0.47981  0.49394  0.50144  0.51750  0.57406
# 230  20180103       GBP  0.47241  0.48094  0.49369  0.50156  0.51844  0.57725
# 231  20180102       GBP  0.47241  0.48088  0.49681  0.50125  0.51906  0.57725
#
#          12m
# 0    1.14100
# ...

# %%
df = pro.shibor_lpr(start_date='20200101', end_date='20200128')
df
# Out:
# Empty DataFrame
# Columns: [date, 1y]
# Index: []

# %%
df = ts.pro_bar(ts_code='300033.SZ', asset='E', freq='D',
                            start_date='20210223', end_date='20210223')
df
# Out:
#      ts_code trade_date    open    high    low  close  pre_close  change  \
# 0  300033.SZ   20210223  149.63  153.36  144.9  145.8      148.0    -2.2
#
#    pct_chg       vol       amount
# 0  -1.4865  72817.93  1083461.451
